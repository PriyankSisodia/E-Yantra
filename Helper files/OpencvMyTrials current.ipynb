# %%
import cv2 as cv
import matplotlib.pyplot as plt

# %%
# %matplotlib inline  ###use matplotlib to open or showimage in jupyter notebook ,else it will crash the notebool
img = cv.imread('1.jpg',-1)
plt.imshow(img)

# %%
import numpy as np
np.set_printoptions(linewidth =200)

# %%
print(img)
# Out:
# [[[254 254 254]
#   [254 254 254]
#   [254 254 254]
#   ...
#   [182 190 207]
#   [185 193 210]
#   [185 193 210]]
#
#  [[254 254 254]
#   [254 254 254]
#   [254 254 254]
#   ...
#   [182 190 207]
#   [181 189 206]
#   [189 197 214]]
#
#  [[254 254 254]
#   [254 254 254]
#   [254 254 254]
#   ...
#   [182 190 207]
#   [170 178 195]
#   [180 188 205]]
#
#  ...
#
#  [[155 146 137]
#   [160 154 143]
#   [126 122 111]
#   ...
#   [ 20  15  16]
#   [  6   1   2]
#   [ 23  18  19]]
#
#  [[173 164 154]
#   [168 162 151]
#   [143 140 126]
#   ...
#   [ 50  45  46]
#   [ 41  36  37]
#   [ 33  28  29]]
#
#  [[154 145 135]
#   [138 132 119]
#   [142 137 122]
#   ...
#   [ 63  57  58]
#   [ 63  57  58]
#   [ 43  37  38]]]

# %%
img = cv.imread('12.jpg',-1)
cv.imshow('image',img)
cv.waitKey(0)
cv.destroyAllWindows() ##use space to exit the image please

# %%
##Visualizing the different color channels of an RGB image.
##in opencv ,image is stored as BGR format and not RGB

# %%
import cv2 as cv
import matplotlib.pyplot as plt
img = cv.imread('RGB_paint.png')
B,G,R =cv.split(img)  ##in open cv it is stored as BGR
cv.imshow('Original',img)
cv.waitKey(0)
#use space to see the next image
cv.imshow('blue',B)
cv.waitKey(0)
#use space to see the next image
cv.imshow('green',G)
cv.waitKey(0)
cv.imshow('red',R)
cv.waitKey(0)
cv.destroyAllWindows()

# %%
###Addition of Image:
##We can add two images by using function cv2.add(). 
##This directly adds up image pixels in the two images.

# %%
#Syntax: cv2.addWeighted(img1, wt1, img2, wt2, gammaValue)
#Parameters:
#img1: First Input Image array(Single-channel, 8-bit or floating-point)
#wt1: Weight of the first input image elements to be applied to the final image
#img2: Second Input Image array(Single-channel, 8-bit or floating-point)
#wt2: Weight of the second input image elements to be applied to the final image
#gammaValue: Measurement of light

# %%
import cv2 as cv
import matplotlib.pyplot as plt
image1 = cv.imread('scene1.jpg')
image2 = cv.imread('scene2.jpg')
weighted_image = cv.addWeighted(image1,0.5,image2,0.4,0)
cv.imshow("scene1",image1)
cv.waitKey(0)
cv.imshow("scene2",image2)
cv.waitKey(0)
cv.imshow("weighted",weighted_image)
cv.waitKey(0)
cv.destroyAllWindows()

# %%
##Subtraction of Image:
#Just like addition, we can subtract the pixel values in two images and 
#merge them with the help of cv2.subtract(). 
#The images should be of equal size and depth.

# %%
import cv2 as cv
import matplotlib.pyplot as plt
image1 = cv.imread('star.jpg')
image2 = cv.imread('dot.jpg')

sub = cv.subtract(image1, image2) 
cv.imshow("substracted",sub)
cv.waitKey(0) 
cv.destroyAllWindows()

# %%
##Bitwise operation on images 
#Bitwise operations are used in image manipulation and 
#used for extracting essential parts in the image. In this article, Bitwise operations used are :

#AND
#OR
#XOR
#NOT

# %%
##two images we will be working with
import cv2 as cv
import matplotlib.pyplot as plt
image1 = cv.imread('halfblackwhite.png')
image2 = cv.imread('whitecircleInBlack.png')
AND = cv.bitwise_and(image1, image2, mask = None) 
cv.imshow("first working image",image1)
cv.waitKey(0) 
cv.imshow("second working image",image2)
cv.waitKey(0) 

cv.imshow("and",AND)
cv.waitKey(0) 
cv.destroyAllWindows()
cv.destroyAllWindows()

# %%
##AND OPERATION
import cv2 as cv
import matplotlib.pyplot as plt
image1 = cv.imread('halfblackwhite.png')
image2 = cv.imread('whitecircleInBlack.png')

AND = cv.bitwise_and(image1, image2, mask = None) 
cv.imshow("and",AND)
cv.waitKey(0) 
cv.destroyAllWindows()

# %%
##OR OPERATION
import cv2 as cv
import matplotlib.pyplot as plt
image1 = cv.imread('halfblackwhite.png')
image2 = cv.imread('whitecircleInBlack.png')

OR= cv.bitwise_or(image1, image2, mask = None) 
cv.imshow("or",OR)
cv.waitKey(0) 
cv.destroyAllWindows()

# %%
##NOT OPERATION
import cv2 as cv
import matplotlib.pyplot as plt
image1 = cv.imread('halfblackwhite.png')
image2 = cv.imread('whitecircleInBlack.png')

NOT1= cv.bitwise_not(image1, mask = None)
NOT2= cv.bitwise_not(image2, mask = None)
cv.imshow("not1",NOT1)
cv.waitKey(0) 
cv.imshow("not2",NOT2)
cv.waitKey(0) 
cv.destroyAllWindows()

# %%
##XOR OPERATION
import cv2 as cv
import matplotlib.pyplot as plt
image1 = cv.imread('halfblackwhite.png')
image2 = cv.imread('whitecircleInBlack.png')

XOR = cv.bitwise_xor(image1, image2, mask = None)
cv.imshow("xor",XOR)
cv.waitKey(0) 
cv.destroyAllWindows()

# %%
##playing video using opencv

# %%
##############################THIs code for video playing is not working
import cv2 as cv
import matplotlib.pyplot as plt

cap = cv.VideoCapture('ballmotion.m4v')
while True:
    success, frame = cap.read()
    cv.imshow('video',frame)
    #cv.waitKey(0)
    #cv.destroyAllWindows()

    if cv.waitKey(25) & 0xFF ==ord('p'):
        break

# %%
############this code is working fine to play videos(not working for live capturing)
import cv2
#capture video
cap = cv2.VideoCapture(0)
#cap.set(3,500)    ##setting for width(3) 
#cap.set(4,500)    ##setting for height(4) 
#cap.set(10,100)   ##setting for brightness
if (cap.isOpened()== False):
    print("Error opening video stream or file")
while (cap.isOpened()):
    # Capture frame-by-frame
    # ret = if the frame is collected or not (boolean),frame = part of video as a frame
    ret, frame = cap.read()
    if ret == True:
 # Display the resulting frame
        cv2.imshow('Frame', frame)
  # Press Q on keyboard to  exit
        if cv2.waitKey(25) & 0xFF == ord('q'):
            break
 # Break the loop
    else:
        break
 # When everything done, release the video capture object(inportant)
cap.release()
cap.release()
cap.release()
cap.release()
 # Closes all the frames
cv2.destroyAllWindows()

# %%
 ##some basic functions

# %%
import cv2 as cv
import numpy as np
kernel = np.ones((5,5),np.uint8)
image = cv.imread('RGB_paint.png')
imgGray = cv.cvtColor(image,cv.COLOR_BGR2GRAY)  #in gray shade
imgBlur = cv.GaussianBlur(image,(7,7),0)   ##gaussian blur with filter 7,7
imgCanny = cv.Canny(image,100,100)    ##finding edges in the image (more values of thresshold ,less will be edges to show onnthe images)
imgDialation = cv.dilate(imgCanny,kernel,iterations =5) ##for thickening the edges of canny image(thickness can be controlled by increasing n of itterations)
imgErode = cv.erode(imgDialation,kernel,iterations=5) ##opposite of dialation(thining of edges )
cv.imshow('normal',image)
cv.waitKey(0)
cv.imshow('gray',imgGray)
cv.waitKey(0)
cv.imshow('blur',imgBlur)
cv.waitKey(0)
cv.imshow('cenny',imgCanny)
cv.waitKey(0)
cv.imshow('dialated image',imgDialation)
cv.waitKey(0)
cv.imshow('eroded image',imgErode)
cv.waitKey(0)
cv.destroyAllWindows()

# %%
##resizing and cropping

# %%
import cv2 as cv
img = cv.imread('scene1.jpg')
print("original shape: ")
print(img.shape)
imgResize = cv.resize(img,(200,200)) ##resize theimage
imgCrop = img[0:200,100:300]   ##treating it as a array ofcourse for cropping
print("resized shape: ")
print(imgResize.shape)
cv.imshow('original image',img)
cv.waitKey(0)
cv.imshow('resized image',imgResize)
cv.waitKey(0)
cv.imshow('cropped image',imgCrop)
cv.waitKey(0)
cv.destroyAllWindows()
# Out:
# original shape:
# (1200, 1920, 3)
# resized shape:
# (500, 500, 3)

# %%
##basics shapes and texts on the image

# %%
import cv2 as cv
import numpy as np
black = np.zeros((500,500))
cv.imshow('black',black)
cv.waitKey(0)
cv.destroyAllWindows()

# %%
import cv2 as cv
import numpy as np
blue = np.zeros((500,500,3),np.uint8)  ##np.uint8 means values of the pixel can range from 0-255 (8 bit image)
blue[:] =255,0,0  ##as it is present in BGR format in CV
redPartial = np.zeros((500,500,3),np.uint8)
redPartial[200:300,100:400] =0,0,255   ##playing with the arrays of images
cv.imshow('blue',blue)
cv.waitKey(0)
cv.imshow('redPartial',redPartial)
cv.waitKey(0)
cv.destroyAllWindows()

# %%
##making line on the image
import cv2 as cv
import numpy as np
black = np.zeros((500,500,3),np.uint8)
black1 = np.zeros((500,500,3),np.uint8)
black2 = np.zeros((500,500,3),np.uint8)

        #image  #startPosition  #EndingPoint  #color      #thickness
cv.line(black,  (0,0),          (300,300),   (0,255,0),   10)
cv.line(black1,(0,0),(black.shape[0],black.shape[1]),(0,255,255),   3)
###rectangle on images
cv.rectangle(black2,(0,0),(200,300),(255,255,0),2) #if we want filled rectangle,use cv.FILLED in place of thickness
cv.circle(black2,(300,400),100,(255,255,255),5) #centre,radius,color,thickness
            #img    #text   #startPosition  #font                 #scale #color  #thicknes
cv.putText(black1,"PRIYANK",(300,200),    cv.FONT_HERSHEY_COMPLEX,  1,   (0,150,0), 4)
cv.imshow('line ',black)
cv.waitKey(0)
cv.imshow('diagonal line ',black1)
cv.waitKey(0)
cv.imshow('rectangle ',black2)
cv.waitKey(0)
cv.destroyAllWindows()

# %%
##warp perspective ##leave it not able to understand this at this time ,if found ,please imporove this
import cv2 as cv
import numpy as np

img = cv.imread("wp2940040.jpg")
width,height = 250,350
pts1 = np.float32([[201,1300],[631,1640],[1100,1040],[680,705]])
pts2 = np.float32([[0,0],[width,0],[0,height],[width,height]])
matrix = cv.getPerspectiveTransform(pts1,pts2)
imgOutput = cv.warpPerspective(img,matrix,(width,height))

cv.imshow('original ',img)
cv.waitKey(0)
cv.imshow('perspective ',imgOutput)
cv.waitKey(0)
cv.destroyAllWindows()

# %%
 ###joining images in a single window
import cv2 
import numpy as np

img = cv2.imread("scene1.jpg")
imgHor = np.hstack((img,img))
imgVert = np.vstack((img,img))
imgGray = cv.cvtColor(img,cv.COLOR_BGR2GRAY)
usingFun = stackImages(0.5,([img,imgGray,img],[imgGray,img,imgGray]))
cv2.imshow('horizontal ',imgHor)
cv2.waitKey(0)
cv2.imshow('vertical ',imgVert)
cv2.waitKey(0)
cv2.imshow('using function',usingFun)
cv2.waitKey(0)
cv2.destroyAllWindows()

# %%
######this function is used to show images in the same window(dont need to memorize the function)
import cv2 
def stackImages(scale,imgArray):
    rows = len(imgArray)
    cols = len(imgArray[0])
    rowsAvailable = isinstance(imgArray[0], list)
    width = imgArray[0][0].shape[1]
    height = imgArray[0][0].shape[0]
    if rowsAvailable:
        for x in range ( 0, rows):
            for y in range(0, cols):
                if imgArray[x][y].shape[:2] == imgArray[0][0].shape [:2]:
                    imgArray[x][y] = cv2.resize(imgArray[x][y], (0, 0), None, scale, scale)
                else:
                    imgArray[x][y] = cv2.resize(imgArray[x][y], (imgArray[0][0].shape[1], imgArray[0][0].shape[0]), None, scale, scale)
                if len(imgArray[x][y].shape) == 2: imgArray[x][y]= cv2.cvtColor( imgArray[x][y], cv2.COLOR_GRAY2BGR)
        imageBlank = np.zeros((height, width, 3), np.uint8)
        hor = [imageBlank]*rows
        hor_con = [imageBlank]*rows
        for x in range(0, rows):
            hor[x] = np.hstack(imgArray[x])
        ver = np.vstack(hor)
    else:
        for x in range(0, rows):
            if imgArray[x].shape[:2] == imgArray[0].shape[:2]:
                imgArray[x] = cv2.resize(imgArray[x], (0, 0), None, scale, scale)
            else:
                imgArray[x] = cv2.resize(imgArray[x], (imgArray[0].shape[1], imgArray[0].shape[0]), None,scale, scale)
            if len(imgArray[x].shape) == 2: imgArray[x] = cv2.cvtColor(imgArray[x], cv2.COLOR_GRAY2BGR)
        hor= np.hstack(imgArray)
        ver = hor
    return ver

# %%
################creating a trackbar for color palette

# %%
import cv2 as cv
import numpy as np
def nothing(a):
    pass
#creating a black image and a window
img = np.zeros((300,800,3),np.uint8)
cv.namedWindow("image")

#create trackbar for color change
                 #trakbarName #windowNmae #startingValue #endingValue 
cv.createTrackbar("R",       "image",      0,            255,      nothing)
cv.createTrackbar("G","image",0,255,nothing) #nothing is passed bcs we need to pass this argument for this funciton to work
cv.createTrackbar("B","image",0,255,nothing)

#create on off functionality
switch = "0:OFF\n1:ON"
cv.createTrackbar(switch,"image",0,1,nothing)
while(True):
    #get current position of trackbars
    cv.imshow('image',img)
    k = cv.waitKey(1) & 0xFF
    if k == 32:  ##when we press space key it will run out, and image window closes,(space=32,esc =27)
        break
    r = cv.getTrackbarPos("R","image")
    g = cv.getTrackbarPos("G","image")
    b = cv.getTrackbarPos("B","image")
    s = cv.getTrackbarPos(switch,"image")
    if s==0:
        img[:]=0
    else:
        img[:]=[b,g,r]
cv.destroyAllWindows()

# %%
###color detection(object detection)(when we need to detect a object with a particular color)

# %%
import cv2 as cv
import numpy as np

def empty(a):
    pass
#create a window
cv.namedWindow("Trackbars")
cv.resizeWindow("Trackbars",640,240)
#For HSV, hue range is [0,179], saturation range is [0,255], and value range is [0,255].
#In HSV, it is easier to represent a color than in BGR color-space.
cv.createTrackbar("Hue Max","Trackbars",20,179,empty)##initial value,#range from 0 to 179
cv.createTrackbar("Hue Min","Trackbars",0,179,empty)
cv.createTrackbar("Sat Max","Trackbars",255,255,empty)##these initial values(20,0,255,36,255,152) are there because of adjusting values in bars
cv.createTrackbar("Sat Min","Trackbars",36,255,empty)
cv.createTrackbar("Val Max","Trackbars",255,255,empty)
cv.createTrackbar("Val Min","Trackbars",152,255,empty)
img = cv.imread("opencv1.jpeg")
while(True):
    imgHsv = cv.cvtColor(img,cv.COLOR_BGR2HSV)
    h_max = cv.getTrackbarPos("Hue Max","Trackbars")
    h_min = cv.getTrackbarPos("Hue Min","Trackbars")
    s_max = cv.getTrackbarPos("Sat Max","Trackbars")
    s_min = cv.getTrackbarPos("Sat Min","Trackbars")
    v_max = cv.getTrackbarPos("Val Max","Trackbars")
    v_min = cv.getTrackbarPos("Val Min","Trackbars")
    #print(h_min,h_max,s_min,s_max,v_min,v_max)
    #fixing the values for min and max threshholds
    lower = np.array([h_min,s_min,v_min])
    upper = np.array([h_max,s_max,v_max])
    #print(lower)
    mask = cv.inRange(imgHsv,lower,upper)
    imgResult = cv.bitwise_and(img,img,mask=mask)
    
    #cv.imshow("original",img)
    #cv.imshow("hsv",imgHsv)
    cv.imshow("mask",mask)
    cv.imshow("final",imgResult) ##this is the color (orange ) we want to extract
    k = cv.waitKey(1) & 0xFF
    if k == 27:  ##when we press space key it will run out, and image window closes,(space=32,esc =27)
        break
    cv.waitKey(1)
    #use esc to escape
cv.waitKey(0)
cv.destroyAllWindows()  ##here we can use that stackImages function to see images in more arranged way

# %%
#####shape/contour detection with finding area of the shape

# %%
import cv2
import numpy as np
 #------------------------------------------------------------------------------------------------------
#stacking function
def stackImages(scale,imgArray):
    rows = len(imgArray)
    cols = len(imgArray[0])
    rowsAvailable = isinstance(imgArray[0], list)
    width = imgArray[0][0].shape[1]
    height = imgArray[0][0].shape[0]
    if rowsAvailable:
        for x in range ( 0, rows):
            for y in range(0, cols):
                if imgArray[x][y].shape[:2] == imgArray[0][0].shape [:2]:
                    imgArray[x][y] = cv2.resize(imgArray[x][y], (0, 0), None, scale, scale)
                else:
                    imgArray[x][y] = cv2.resize(imgArray[x][y], (imgArray[0][0].shape[1], imgArray[0][0].shape[0]), None, scale, scale)
                if len(imgArray[x][y].shape) == 2: imgArray[x][y]= cv2.cvtColor( imgArray[x][y], cv2.COLOR_GRAY2BGR)
        imageBlank = np.zeros((height, width, 3), np.uint8)
        hor = [imageBlank]*rows
        hor_con = [imageBlank]*rows
        for x in range(0, rows):
            hor[x] = np.hstack(imgArray[x])
        ver = np.vstack(hor)
    else:
        for x in range(0, rows):
            if imgArray[x].shape[:2] == imgArray[0].shape[:2]:
                imgArray[x] = cv2.resize(imgArray[x], (0, 0), None, scale, scale)
            else:
                imgArray[x] = cv2.resize(imgArray[x], (imgArray[0].shape[1], imgArray[0].shape[0]), None,scale, scale)
            if len(imgArray[x].shape) == 2: imgArray[x] = cv2.cvtColor(imgArray[x], cv2.COLOR_GRAY2BGR)
        hor= np.hstack(imgArray)
        ver = hor
    return ver
#-----------------------------------------------------------------------------------------------------
#function to get contours
def getContours(img):
    _ , contours, heirarchy = cv2.findContours(img,cv2.RETR_EXTERNAL,cv2.CHAIN_APPROX_NONE)
    for cnt in contours:
        area = cv2.contourArea(cnt)
        print(area)
        #contour on image--#img   #countour #index #color #thickness
        if area>500: #to avoid the noise in the image
            cv2.drawContours(imgContour,cnt,-1,(255,0,0),3)#index =-1 means all the countours
            perimeter = cv2.arcLength(cnt,True) #it gives the perimeter of each shape(true is for closed shape)
            aprox = cv2.approxPolyDP(cnt,0.02*perimeter,True) #this will give coridinates of all the corner points
            print(len(aprox)) #this will print number of corneres in each cotour
            n_corners = len(aprox)
            #now we will draw a rounded box around the detected object(or shape)
            x, y, w, h = cv2.boundingRect(aprox) #this function takes the corners cordinates of shape and returns the x,y,width,hight of the bounding box(x,y are top left corner cordinate)
            cv2.rectangle(imgContour,(x,y),(x+w,y+h),(0,0,255),2) #draw a bounding rect with the corinates we got (x,y)=tope left,(x+w,y+h)=right bottom corner
            obj = "none"
            if n_corners ==3: 
                obj = "triangle"
            cv2.putText(imgContour,obj,(x+(w//2-10),y+(h//255-10)),cv2.FONT_HERSHEY_COMPLEX,0.5,(0,0,0),2)
        
        ##till now it will draw all the contours in the image
#-----------------------------------------------------------------------------------------------------
#Starting function
img = cv2.imread("shapes.png")

imgGray = cv2.cvtColor(img,cv2.COLOR_BGR2GRAY)
imgBlur = cv2.GaussianBlur(imgGray,(7,7),1)
imgCanny = cv2.Canny(imgBlur,50,50)
imgContour = img.copy()
imgBlank = np.zeros_like(img) #zeroes matrix of shape as same as img
#cv.imshow("Gray",imgGray)
#cv.imshow("ORIGINAL",img)
#cv.imshow("blur",imgBlur)
getContours(imgCanny)
imgStack = stackImages(0.5,([img,imgGray,imgBlur],[imgCanny,imgContour,imgBlank]))
cv2.imshow("stack",imgStack)
cv2.waitKey(0)
cv2.destroyAllWindows()
#------------------------------------------------------------------------------------------------------
#some theory

#For better accuracy, use binary images. 
#So before finding contours, apply threshold or canny edge detection.
#In OpenCV, finding contours is like finding white object from black background. 
#So remember, object to be found should be white and background should be black.
#---------
##If you pass cv2.CHAIN_APPROX_NONE, all the boundary points are stored.
#But actually do we need all the points? For eg, you found the contour of a straight line. Do you need all the points on the line to represent that line? No, we need just two end points of that line. This is what cv2.CHAIN_APPROX_SIMPLE does.
#It removes all redundant points and compresses the contour, thereby saving memory.
#---------
# Out:
# 3593.5
# 8
# 8619.0
# 4
# 10398.5
# 4
# 10236.0
# 8
# 1612.5
# 3
# 10402.0
# 4
# 6389.0
# 4
# 5629.0
# 3
# 3475.5
# 4
# 2270.5
# 4
# 3552.5
# 8
# 8674.0
# 4
# 2646.0
# 4
# 5690.5
# 3
# 10234.0
# 8
# 5712.0
# 3

# %%
import cv2 
import time
cap = cv2.VideoCapture(0)

time.sleep(30)
cap.release()

# %%
import cv2

cap = cv2.VideoCapture(0)

while True:
    ret,img = cap.read()
    if ret == False:
    	break
    cv2.imshow('magic',img)
    k=cv2.waitKey(1)
    if(k==ord('q')) :
        break

cap.release()
cv2.destroyAllWindows()

# %%
#perspective view of the image

import numpy as np
import cv2 as cv

#taking image-> gray-> canny ->findContour->draw contour on blank image
img = cv.imread('maze05.jpg')
imgGray = cv.cvtColor(img,cv.COLOR_BGR2GRAY)
imgBlur = cv.GaussianBlur(imgGray,(7,7),1)
ret,imgThresh = cv.threshold(imgBlur,100,255,cv2.THRESH_BINARY)
imgBlank = np.zeros_like(img)
imgCanny = cv.Canny(imgThresh,80,80)
_ , contours, heirarchy = cv.findContours(imgCanny,cv.RETR_EXTERNAL,cv.CHAIN_APPROX_NONE)
#print(len(contours))
for cnt in contours:
    cv.drawContours(imgBlank,cnt,-1,(255,0,0),4)
    parameter = cv.arcLength(cnt,True)
    corners = cv.approxPolyDP(cnt, 0.02*parameter,True)
    print(f"initial cordinates:",corners)
    #==================================================================================
    #ordering all the corners(output of aproxpoly give unordered cordinates of shape)
    rect = np.zeros((4, 2), dtype="float32")
    # the top-left point will have the smallest sum, whereas
    # the bottom-right point will have the largest sum
    s = corners.sum(axis=2)
    rect[0] = corners[np.argmin(s)]
    rect[2] = corners[np.argmax(s)]
    # now, compute the difference between the points, the
    # top-right point will have the smallest difference,
    # whereas the bottom-left will have the largest difference
    diff = np.diff(corners, axis=2)
    rect[1] = corners[np.argmin(diff)]
    rect[3] = corners[np.argmax(diff)]
    #order = topleft,topright,bottomright,bottomleft
    print(f"final cordinates:",rect)
    #==================================================================================
    #applying perspective transform
    (tl, tr, br, bl) = rect
    # compute the width of the new image, which will be the
    # maximum distance between bottom-right and bottom-left
    # x-coordiates or the top-right and top-left x-coordinates
    widthA = np.sqrt(((br[0] - bl[0]) ** 2) + ((br[1] - bl[1]) ** 2))
    widthB = np.sqrt(((tr[0] - tl[0]) ** 2) + ((tr[1] - tl[1]) ** 2))
    maxWidth = max(int(widthA), int(widthB))
    # compute the height of the new image, which will be the
    # maximum distance between the top-right and bottom-right
    # y-coordinates or the top-left and bottom-left y-coordinates
    heightA = np.sqrt(((tr[0] - br[0]) ** 2) + ((tr[1] - br[1]) ** 2))
    heightB = np.sqrt(((tl[0] - bl[0]) ** 2) + ((tl[1] - bl[1]) ** 2))
    maxHeight = max(int(heightA), int(heightB))
    # now that we have the dimensions of the new image, construct
    # the set of destination points to obtain a "birds eye view",
    # (i.e. top-down view) of the image, again specifying points
    # in the top-left, top-right, bottom-right, and bottom-left
    # order
    dst = np.array([
        [0, 0],
        [maxWidth - 1, 0],
        [maxWidth - 1, maxHeight - 1],
        [0, maxHeight - 1]], dtype = "float32")
    print(dst)
    # compute the perspective transform matrix and then apply it
    M = cv.getPerspectiveTransform(rect, dst)
    warped = cv.warpPerspective(imgGray, M, (maxWidth, maxHeight))
    #===================================================================================
    
    
#showing output images
#imageStack = stackImages(0.5,([img,imgGray,imgThresh],[imgCanny,warped,imgBlank]))
cv.imshow("output",warped)
cv.waitKey(0)
cv.destroyAllWindows()
